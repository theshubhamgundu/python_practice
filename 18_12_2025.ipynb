# %% [markdown]
# <a href="https://colab.research.google.com/github/Ram6023/python-practice/blob/main/18_12_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib

# %%
pip install seaborn

# %%
import seaborn as sns
df=sns.load_dataset("tips")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-549652835.py in <cell line: 0>()
# ----> 1 df=sns.load_dataset("tips")
#
# NameError: name 'sns' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
sns.get_dataset_names ()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.median(numeric_only=True)
# Out:
# total_bill    17.795
# tip            2.900
# size           2.000
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#    total_bill  tip  size
# 0       13.42  2.0     2

# %%
df.mean(numeric_only=True)
# Out:
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %%
df['tip'].max()
# Out:
# 10.0

# %%
df['tip'].min()
# Out:
# 1.0

# %%
print(f"""
Insights

1. Dataset Size & Reliability
{df.shape[0]} records for all columns → no missing values.

2. Total Bill
Average: {df['total_bill'].mean():.2f}
Median: {df['total_bill'].median():.2f}
Max: {df['total_bill'].max():.2f}

3. Tip
Average: {df['tip'].mean():.2f}
Median: {df['tip'].median():.2f}
Max: {df['tip'].max():.2f}

4. Party Size
Average size: {df['size'].mean():.2f}
Median: {df['size'].median()}
Max: {df['size'].max()}
""")
# Out:
# Insights
#
# 1. Dataset Size & Reliability
# 244 records for all columns → no missing values.
#
# 2. Total Bill
# Average: 19.79
# Median: 17.80
# Max: 50.81
#
# 3. Tip
# Average: 3.00
# Median: 2.90
# Max: 10.00
#
# 4. Party Size
# Average size: 2.57
# Median: 2.0
# Max: 6

# %%
# Generate human-readable insights like the screenshot

insights = """
Insights

1. total_bill
Most bills fall between $10–$20, with a few very large ones.
Higher bills usually lead to higher tips, but not always proportionally.

2. tip
Tips range mostly from $2–$4, skewed toward smaller amounts.
They grow with bill size, but tip percentage varies widely.

3. sex
Males tend to leave slightly higher tips in absolute terms.
When normalized by bill size, gender differences are minimal.

4. smoker
Smokers and non-smokers tip at similar rates.
Smokers often appear in smaller dining groups.

5. day
Weekends (Sat/Sun) show larger bills and higher tips.
Weekdays (Thur/Fri) have smaller bills and fewer customers.

6. time
Lunch bills are smaller with lower tips.
Dinner bills are larger, often with alcohol, leading to bigger tips.

7. size
Group size ranges from 1–6, with bigger groups spending more.
Tip percentage tends to drop slightly as group size increases.
"""

print(insights)
# Out:
# Insights
#
# 1. total_bill
# Most bills fall between $10–$20, with a few very large ones.
# Higher bills usually lead to higher tips, but not always proportionally.
#
# 2. tip
# Tips range mostly from $2–$4, skewed toward smaller amounts.
# They grow with bill size, but tip percentage varies widely.
#
# 3. sex
# Males tend to leave slightly higher tips in absolute terms.
# When normalized by bill size, gender differences are minimal.
#
# 4. smoker
# Smokers and non-smokers tip at similar rates.
# Smokers often appear in smaller dining groups.
#
# 5. day
# Weekends (Sat/Sun) show larger bills and higher tips.
# Weekdays (Thur/Fri) have smaller bills and fewer customers.
#
# 6. time
# Lunch bills are smaller with lower tips.
# Dinner bills are larger, often with alcohol, leading to bigger tips.
#
# 7. size
# Group size ranges from 1–6, with bigger groups spending more.
# Tip percentage tends to drop slightly as group size increases.

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.isnull().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    bool
#  1   tip         244 non-null    bool
#  2   sex         244 non-null    bool
#  3   smoker      244 non-null    bool
#  4   day         244 non-null    bool
#  5   time        244 non-null    bool
#  6   size        244 non-null    bool
# dtypes: bool(7)
# memory usage: 1.8 KB

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.dropna().shape
# Out:
# (182, 15)

# %%
((df.shape[0]-df.dropna().shape[0])/df.shape[0])*100 #
# Out:
# 79.57351290684625

# %%
((891-182)/891)*100
# Out:
# 79.57351290684625

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df = df.drop(columns=['deck'])

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %% [markdown]
# **UNIVARIATE**

# %%
plt.figure(figsize=(5,5))
sns.histplot (x=df['survived'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot (x=df['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot (x=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot (x=df['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot (x=df['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot (x=df['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot (x=df['alone'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot (x=df['embarked'])
plt.show()

# %% [markdown]
# BIVARIATE

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['sex' ])
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['who' ])
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['class' ])
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['pclass' ])
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['fare' ])
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alive' ])
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['embarked' ])
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['sibsp' ])
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alone' ])
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['parch' ])
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['adult_male' ])
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['survived' ])
plt. show()

# %%
# bivariate analysis

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived' ],hue=df['sex'],kde=True)
plt.show()

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age' ],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass' ],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp' ],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch' ],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare' ],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['embarked' ],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['class' ],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['who' ],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['embark_town' ],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['adult_male' ],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['alive' ],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['alone' ],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived' ],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare' ],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sex' ],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass' ],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age' ],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived' ],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot (x=df['sex' ],hue=df ['embarked' ])

plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['sex'],hue=df['alone' ])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['class'],hue=df['alive' ])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alive'],hue=df['alone' ])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alive'],hue=df['embarked' ])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['embarked'],hue=df['sex' ])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['class'],hue=df['embarked' ])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['embarked'],hue=df['parch' ])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['parch'],hue=df['alive' ])
plt.show()
